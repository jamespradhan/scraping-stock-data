# %%
import pandas as pd

# %%
raw_data = pd.read_csv("data/raw-data/ind_nifty50list.csv")

# %%
raw_data.head()
# Out:
#                                  Company Name            Industry      Symbol  \
# 0                      Adani Enterprises Ltd.     Metals & Mining    ADANIENT
# 1  Adani Ports and Special Economic Zone Ltd.            Services  ADANIPORTS
# 2            Apollo Hospitals Enterprise Ltd.          Healthcare  APOLLOHOSP
# 3                           Asian Paints Ltd.   Consumer Durables  ASIANPAINT
# 4                              Axis Bank Ltd.  Financial Services    AXISBANK
#
#   Series     ISIN Code
# 0     EQ  INE423A01024
# 1     EQ  INE742F01042
# 2     EQ  INE437A01024
# 3     EQ  INE021A01026
# 4     EQ  INE238A01034

# %%
raw_data["Series"].value_counts()
# Out:
# Series
# EQ    50
# Name: count, dtype: int64

# %%
raw_data["Industry"].value_counts()
# Out:
# Industry
# Financial Services                11
# Healthcare                         5
# Automobile and Auto Components     5
# Information Technology             5
# Metals & Mining                    4
# Fast Moving Consumer Goods         4
# Oil Gas & Consumable Fuels         3
# Services                           2
# Consumer Durables                  2
# Consumer Services                  2
# Construction Materials             2
# Power                              2
# Capital Goods                      1
# Telecommunication                  1
# Construction                       1
# Name: count, dtype: int64

# %%
raw_data.drop(columns=["Series", "ISIN Code"], inplace=True)
raw_data.head()
# Out:
#                                  Company Name            Industry      Symbol
# 0                      Adani Enterprises Ltd.     Metals & Mining    ADANIENT
# 1  Adani Ports and Special Economic Zone Ltd.            Services  ADANIPORTS
# 2            Apollo Hospitals Enterprise Ltd.          Healthcare  APOLLOHOSP
# 3                           Asian Paints Ltd.   Consumer Durables  ASIANPAINT
# 4                              Axis Bank Ltd.  Financial Services    AXISBANK

# %%
raw_data.columns = ["name", "industry", "symbol"]

# %%
raw_data["symbol"] = raw_data["symbol"] + ".NS"
raw_data.head()
# Out:
#                                          name            industry  \
# 0                      Adani Enterprises Ltd.     Metals & Mining
# 1  Adani Ports and Special Economic Zone Ltd.            Services
# 2            Apollo Hospitals Enterprise Ltd.          Healthcare
# 3                           Asian Paints Ltd.   Consumer Durables
# 4                              Axis Bank Ltd.  Financial Services
#
#           symbol
# 0    ADANIENT.NS
# 1  ADANIPORTS.NS
# 2  APOLLOHOSP.NS
# 3  ASIANPAINT.NS
# 4    AXISBANK.NS

# %%
file_name = "nifty-50.csv"
raw_data.to_csv(f"data/index-constituent/{file_name}", index=False)
