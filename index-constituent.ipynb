# %%
import pandas as pd

# %%
raw_data = pd.read_csv("raw-data/ind_nifty200list.csv")

# %%
raw_data.head()
# Out:
#                   Company Name            Industry      Symbol Series  \
# 0             360 ONE WAM Ltd.  Financial Services      360ONE     EQ
# 1               ABB India Ltd.       Capital Goods         ABB     EQ
# 2        APL Apollo Tubes Ltd.       Capital Goods   APLAPOLLO     EQ
# 3   AU Small Finance Bank Ltd.  Financial Services      AUBANK     EQ
# 4  Adani Energy Solutions Ltd.               Power  ADANIENSOL     EQ
#
#       ISIN Code
# 0  INE466L01038
# 1  INE117A01022
# 2  INE702C01027
# 3  INE949L01017
# 4  INE931S01010

# %%
raw_data["Series"].value_counts()
# Out:
# Series
# EQ    200
# Name: count, dtype: int64

# %%
raw_data["Industry"].value_counts()
# Out:
# Industry
# Financial Services                48
# Capital Goods                     23
# Healthcare                        16
# Automobile and Auto Components    14
# Fast Moving Consumer Goods        14
# Information Technology            12
# Consumer Services                 11
# Metals & Mining                   10
# Oil Gas & Consumable Fuels         9
# Power                              8
# Consumer Durables                  8
# Chemicals                          6
# Realty                             6
# Services                           4
# Construction Materials             4
# Telecommunication                  4
# Construction                       2
# Textiles                           1
# Name: count, dtype: int64

# %%
raw_data.drop(columns=["Series", "ISIN Code"], inplace=True)
raw_data.head()
# Out:
#                   Company Name            Industry      Symbol
# 0             360 ONE WAM Ltd.  Financial Services      360ONE
# 1               ABB India Ltd.       Capital Goods         ABB
# 2        APL Apollo Tubes Ltd.       Capital Goods   APLAPOLLO
# 3   AU Small Finance Bank Ltd.  Financial Services      AUBANK
# 4  Adani Energy Solutions Ltd.               Power  ADANIENSOL

# %%
raw_data.columns = ["name", "industry", "symbol"]

# %%
raw_data["symbol"] = raw_data["symbol"] + ".NS"
raw_data.head()
# Out:
#                           name            industry         symbol
# 0             360 ONE WAM Ltd.  Financial Services      360ONE.NS
# 1               ABB India Ltd.       Capital Goods         ABB.NS
# 2        APL Apollo Tubes Ltd.       Capital Goods   APLAPOLLO.NS
# 3   AU Small Finance Bank Ltd.  Financial Services      AUBANK.NS
# 4  Adani Energy Solutions Ltd.               Power  ADANIENSOL.NS

# %%
file_name = "nifty-200.csv"
raw_data.to_csv(f"index-constituent/{file_name}", index=False)
